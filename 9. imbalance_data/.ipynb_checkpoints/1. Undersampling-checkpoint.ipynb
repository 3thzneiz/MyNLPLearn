# %%
import pandas as pd
full_df = pd.read_csv(open('/Volumes/MyPassport/text privacy/10_06.csv', 'r'), sep='\t')

# %%
full_df
# Out:
#       Unnamed: 0  index                                           apk_name  \
# 0              0      0                          jp.ne.ibis.ibispaintx.app
# 1              1      1                                   com.canva.editor
# 2              2      2                               com.vblast.flipaclip
# 3              3      3                              com.wallsstudio.bnk48
# 4              4      4                  com.medibang.android.paint.tablet
# 5              5      5                               com.eyewind.paperone
# 6              6      6                                    app.over.editor
# 7              7      7                 air.com.KalromSystems.SandDrawLite
# 8              8      8                  com.Muziizen.ChineseNewYearFrames
# 9              9      9                             com.sevelina.sisterspj
# 10            10     10                          com.wahyuashari.glitchapp
# ...
